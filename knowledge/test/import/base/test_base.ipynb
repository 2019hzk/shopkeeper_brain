# %% [markdown]
# ## 1. 测试Path使用

# %%
from pathlib import Path

pdf_path = r"D:\develop\develop\workspace\pycharm\251020\shopkeeper_brain\knowledge\processor\import_process\import_temp_dir\万用表的使用.pdf"

path = Path(pdf_path)

# path.suffix

path.stem
# Out:
# '万用表的使用'

# %%
import  os
test_dir = r"D:\develop\develop\workspace\pycharm\251020\shopkeeper_brain\knowledge\processor\import_process\import_temp_dir"


for file_name in os.listdir(test_dir):
    print(os.path.splitext(file_name))
# Out:
# ('万用表的使用', '')
# ('万用表的使用', '.pdf')

# %%
test1=["1","2","3"]
print("\n\n".join(test1))
# Out:
# 1
#
# 2
#
# 3

# %%
test_list=['1','2','3']

test=list(test_list.reverse())

for i in test:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 test_list=['1','2','3']
# ----> 3 test=list(test_list.reverse())
#       5 for i in test:
#       6     print(i)
#
# TypeError: 'NoneType' object is not iterable
